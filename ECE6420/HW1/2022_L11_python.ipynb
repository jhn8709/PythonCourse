# %% [markdown]
# # Look at Home page
#
# - files and open an existing files
# - create a new file

# %% [markdown]
# ---

# %% [markdown]
# # Look at the Notebook page

# %% [markdown]
# - Notebook name
# - menu bar
# - tool bar

# %% [markdown]
# ---

# %% [markdown]
# # Introduction to Jupyter Notebook
#
# ## Create a cell
#
# - `insert`
# - `A` or `B` in the commander mode

# %% [markdown]
# ### Run some code in a `Code` cell and get results immediately
#
# ```python
# 1 + 2
# ```
#
# ```python
# # Copy-paste into a new cell
# print('hello, world!')
# ```

# %% [markdown]
# ### Visualize data and show a picuture
#
# ```python
# from matplotlib import pyplot as plt
# import numpy as np
#
# # Generate 100 random data points along 3 dimensions
# x, y, scale = np.random.randn(3, 100)
# fig, ax = plt.subplots()
#
# # Map each onto a scatterplot we'll create with Matplotlib
# ax.scatter(x=x, y=y, c=scale, s=np.abs(scale)*500)
# ax.set(title="Some random data, created with JupyterLab!")
# plt.show()
# ```

# %% [markdown]
# ## Change a cell type
#
# The default type is `Code`. Change it to `mardown`.

# %% [markdown]
# # Markdown syntax
#
# ### Headings
#
# ```
# # heading 1
# ## heading 2
# ### heading 3
# #### heading 4
# ##### heading 5
# ##### heading 6
# ```
#
# ### Emphasis
#
# #### Bold
# ```
# I just love **bold text**.
# I just love __bold text__.
# ```
#
# #### Italic
#
# ```
# Italicized text is the *cat's meow*.
# Italicized text is the _cat's meow_.
# ```

# %% [markdown]
# Italicized text is the *cat's meow*

# %% [markdown]
# ### List
#
# #### Ordered list
#
# ```
# 1. First item
# 2. Second item
# 5. Third item
# 4. Fourth item
# ```
#
# #### Unordered list
# ```
# - First item
# - Second item
# - Third item
# - Fourth item
# ```

# %% [markdown]
# ### Images
#
#
# ```
# ![Clemson Logo](https://logos-world.net/wp-content/uploads/2021/08/Clemson-University-Logo-700x394.png)
# ```

# %% [markdown]
# ### Links
#
# ```
# [Clemson University](https://www.clemson.edu/)
# ```

# %% [markdown]
# ### Code Blocks

# %% [raw]
# ```python
# print('hello, world')
# x = 3 - 1
# ```

# %% [markdown]
# ### More
#
# More information at [Markdown Guide](https://www.markdownguide.org/basic-syntax/)
